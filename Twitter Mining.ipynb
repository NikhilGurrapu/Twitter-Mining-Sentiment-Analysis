# %%
#https://apps.twitter.com/

import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob 
  
class TwitterClient(object): 
    def __init__(self): 
        consumer_key = '<<your_consumer_key>>'
        consumer_secret = '<<your_consumer_secret>>'
        access_token = '<<you_access_token>>'
        access_token_secret = '<<your_access_token_secret>>'

        try: 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            self.auth.set_access_token(access_token, access_token_secret) 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 
  
    def get_tweet_sentiment(self, tweet): 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        else: 
            return 'negative'
  
    def get_tweets(self, query, count = 10): 
        tweets = [] 
  
        try: 
            fetched_tweets = self.api.search_tweets(q = query, count = count) 
            for tweet in fetched_tweets: 
                parsed_tweet = {} 
                parsed_tweet['text'] = tweet.text 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
                if tweet.retweet_count > 0:  
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
            return tweets 
  
        except tweepy.TweepyException as e: 
            print("Error : " + str(e)) 
def main(): 
    api = TwitterClient() 
    tweets = api.get_tweets(query = 'KashmirFiles', count = 200) 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text'])  
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 
if __name__ == "__main__":  
    main()
# Out:
# Positive tweets percentage: 23.404255319148938 %
# Negative tweets percentage: 76.59574468085107 %
#
#
# Positive tweets:
# RT @ashokepandit: Madame the success of #Kashmirfiles has hit you so hard that you have lost your balance of mind.
# Abusing Manoj Kumar ji…
# RT @MadanKandal3: #KashmirFiles.So very happy that atlast PM and BJP have felt the pain of KPs.Hope something concrete is now done for redr…
# RT @GemsOfBollywood: As per Diljale (1996), the greatest terrorists of Kashmir were a Hindu Shyam (@ajaydevgn) and his mentor  Dara!
#
# #Kash…
# Watching #Kashmirfiles. A really tragic tale and more importantly we the people of India and our govt machinery let… https://t.co/IpH31vPRnJ
# #KashmirFiles.So very happy that atlast PM and BJP have felt the pain of KPs.Hope something concrete is now done fo… https://t.co/iVp1muW5Hs
# RT @SongsOfChinar: Main rann ke liye taiyyar baitha hoon!
# #KashmirFiles
# #IndianArmy https://t.co/HjoVngjg37
# RT @rajiv_pandit: This is how my mama ji (uncle) escaped a bullet from Bitta Karate and is still alive today. I have not told this story be…
# RT @LageRahoKashmir: That's Lt Gen DPP on 02 April for soft launch of #KashmirsFloatingVillage #KachriMohalla for  @aliahd66
# #KashmirFiles…
# RT @KashmirFiles: What qualifies for a ‘free YouTube video’?
# @vivekagnihotri in conversation with @navikakumar @TNNavbharat https://t.co/UP…
# @KPHSDwarka #CelebratED the #oldest surviving @SAPTRISHI_ calendar #NewYear #5098 and #zangtrei and generated aware… https://t.co/U63EEG0C8B
#
#
# Negative tweets:
# @aitcsudip @abhishekaitc “There is #FuelPriceHike ,prices of essential medicines hiked,extra taxes are imposed on l… https://t.co/2clwJX0YhV
# Saw Kashmir Files today and I heard an old lady behind me with tears in her eyes whisper to her husband “Yeh toh aa… https://t.co/rHc4Wm5ttI
# RT @Indiakibari: #KashmirFiles पर ठहाके लगा खास जमात में प्रसिद्ध हो चुके &amp; पंजाब चुनाव में लंबी फेंकने के बाद फंड मांगने वाले @ArvindKejri…
# RT @CongressAchhi: जिस फ़िल्म का प्रचार देश का प्रधानमंत्री और पूरी भाजपा कर रही है उसकी कमाई नही हो रही है ?
# ऐसा कहना है फ़िल्म के डायरे…
# RT @ashokepandit: Yami ji, they have lost their identity because films like #KashmirFiles &amp; #Dasvi have made them redundant. This reaction…
# RT @KashmirFiles: We thank @kp_global for organising the felicitation ceremony for the team #TheKashmirFiles in presence of Honourable Unio…
# RT @KrishnaChatta13: ON BEHALF OF 1.35 BILLION &amp; SOON TO BE 2 BILLION, we NOMINATE FOR OSCARS AS
#
# BIG APPLAUSE
#
# #Oscars2022 #AcademyAward…
# RT @GemsOfBollywood: Do you know that a child actor of @VishalBhardwaj's #Haider on whose head @shahidkapoor put a skull become a dreaded t…
# RT @iMac_too: Aha! Shikara Queen is harassing an actor coz she backed #KashmirFiles
# RT @vimal045Y: should have taken care  or should have shown Responsibility while showing or referring about our  Army.
#
#   Bollywood:- Movie…
